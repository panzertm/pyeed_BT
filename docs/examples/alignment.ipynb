# %% [markdown]
# # Align sequences

# %%
import logging
logging.basicConfig()
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

import json
from pyeed.core import ProteinRecord


# load accession ids from json file
with open("ids.json", "r") as f:
    ids = json.load(f)

sequences = ProteinRecord.get_ids(ids)
# Out:
# Output()
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/max/miniconda3/envs/pyeed/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:pyeed.fetch.requester:Creating 2 tasks
# DEBUG:pyeed.fetch.requester:Sending 2 requests
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/max/miniconda3/envs/pyeed/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:pyeed.fetch.requester:Creating 48 tasks
# DEBUG:pyeed.fetch.requester:Sending 48 requests
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/max/miniconda3/envs/pyeed/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:pyeed.fetch.requester:Creating 48 tasks
# DEBUG:pyeed.fetch.requester:Sending 48 requests
# DEBUG:pyeed.fetch.requester:Sending request to https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&retmode=text&rettype=genbank&id=TMJ11138,WCN31494,RLE93954,MCI2415466,NQE45598,MBP7070042,PLJ76955,RUM32465,NOZ59931,MCL4350655
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8ZYP7
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8ZYP7
# DEBUG:httpcore.connection:connect_tcp.started host='eutils.ncbi.nlm.nih.gov' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='www.ebi.ac.uk' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.started host='www.ebi.ac.uk' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A4G0T1
# DEBUG:httpcore.connection:connect_tcp.started host='www.ebi.ac.uk' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x166dd1850>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb770> server_hostname='www.ebi.ac.uk' timeout=120
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167a7e510>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb800> server_hostname='www.ebi.ac.uk' timeout=120
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x165b46d50>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb6e0> server_hostname='eutils.ncbi.nlm.nih.gov' timeout=120
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167bb0850>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb800> server_hostname='www.ebi.ac.uk' timeout=120
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A4G0T1
# DEBUG:httpcore.connection:connect_tcp.started host='www.ebi.ac.uk' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q4JAL1
# DEBUG:httpcore.connection:connect_tcp.started host='www.ebi.ac.uk' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167b7ac50>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x16698d990>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x166dd0550>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb800> server_hostname='www.ebi.ac.uk' timeout=120
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167afbd50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167b78c90>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb770> server_hostname='www.ebi.ac.uk' timeout=120
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8ZYP7 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8ZYP7. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8ZYP7>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8ZYP7>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8ZYP7>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7027')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8ZYP7 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8ZYP7. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A4G0T1 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A4G0T1. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8TV85
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x173472c50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x1765ed250>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x178064e50>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8TV85 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q8TV85. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q4JAL1 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q4JAL1. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A4G0T1>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A4G0T1>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A4G0T1>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7005')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A4G0T1 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A4G0T1. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q4JAL1
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A8MD44
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q4JAL1>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q4JAL1>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q4JAL1>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7054')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q4JAL1 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q4JAL1. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2701')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A8MD44 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A8MD44. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&retmode=text&rettype=genbank&id=NHV96297,MCD6512403,MBU7022768,MCL4451275,WP_248897180,WP_211530438,RLF67685,NPA53530
# DEBUG:httpcore.connection:connect_tcp.started host='eutils.ncbi.nlm.nih.gov' port=443 local_address=None timeout=120 socket_options=None
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A6UU75
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A6UU75 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A6UU75. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8TV85
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A1RSD7
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x17344db10>
# DEBUG:httpcore.connection:start_tls.started ssl_context=<ssl.SSLContext object at 0x1765cb6e0> server_hostname='eutils.ncbi.nlm.nih.gov' timeout=120
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8TV85>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8TV85>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=Q8TV85>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7172')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8TV85 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q8TV85. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A1RSD7 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A1RSD7. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q3IQF5
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2115')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q3IQF5 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q3IQF5. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A8MD44
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A0B742
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.connection:start_tls.complete return_value=<httpcore._backends.anyio.AnyIOStream object at 0x167a8d490>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A0B742 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A0B742. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q5JF22
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Sat, 22 Jun 2024 09:47:15 GMT'), (b'Server', b'Finatra'), (b'Strict-Transport-Security', b'max-age=31536000; includeSubDomains; preload'), (b'Content-Security-Policy', b'upgrade-insecure-requests'), (b'Referrer-Policy', b'origin-when-cross-origin'), (b'NCBI-SID', b'9757CFB18E57EFDC_D235SID'), (b'NCBI-PHID', b'939B5CB8DBC099E50000369E8D511CE4.1.1.m_5'), (b'Content-Type', b'text/plain'), (b'Cache-Control', b'private'), (b'content-encoding', b'gzip'), (b'X-RateLimit-Limit', b'3'), (b'Content-Disposition', b'attachment; filename="sequence.gp"'), (b'X-RateLimit-Remaining', b'2'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Expose-Headers', b'X-RateLimit-Limit,X-RateLimit-Remaining'), (b'Set-Cookie', b'ncbi_sid=9757CFB18E57EFDC_D235SID; domain=.nih.gov; path=/; expires=Sun, 22 Jun 2025 09:47:15 GMT'), (b'X-UA-Compatible', b'IE=Edge'), (b'X-XSS-Protection', b'1; mode=block'), (b'Keep-Alive', b'timeout=4, max=40'), (b'Connection', b'Keep-Alive'), (b'Transfer-Encoding', b'chunked')])
# INFO:httpx:HTTP Request: GET https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=protein&retmode=text&rettype=genbank&id=TMJ11138,WCN31494,RLE93954,MCI2415466,NQE45598,MBP7070042,PLJ76955,RUM32465,NOZ59931,MCL4350655 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:16 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2249')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q5JF22 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q5JF22. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A6UU75
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A9A923
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A8MD44>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A8MD44>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A8MD44>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7320')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A8MD44 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A8MD44. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A6UU75>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A6UU75>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A6UU75>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'7023')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A6UU75 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A6UU75. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:16 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A9A923 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A9A923. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A5UMW7
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:16 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2252')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A5UMW7 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/A5UMW7. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A1RSD7
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/P0DF56
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'Grizzly/4.0.2'), (b'X-Pagination-TotalRecords', b'1'), (b'Vary', b'Accept'), (b'Content-Type', b'application/json'), (b'Access-Control-Allow-Credentials', b'true'), (b'Access-Control-Expose-Headers', b'Content-Type, X-UniProt-Release, Link, X-Pagination-TotalRecords, x-feature-records'), (b'Strict-Transport-Security', b'max-age=0'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A1RSD7>; rel="self"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A1RSD7>; rel="first"'), (b'Link', b'<https://www.ebi.ac.uk/proteins/api/proteins?offset=0&size=100&accession=A1RSD7>; rel="last"'), (b'Access-Control-Allow-Origin', b'*'), (b'Access-Control-Allow-Headers', b'origin, content-type, accept, authorization'), (b'Access-Control-Allow-Methods', b'GET, POST, PUT, DELETE, OPTIONS, HEAD'), (b'Content-Length', b'6924')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A1RSD7 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=A1RSD7. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:16 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'1820')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/P0DF56 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/P0DF56. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/O59488
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Server', b'gunicorn'), (b'Vary', b'Accept,Cookie,Origin'), (b'Content-Type', b'application/json'), (b'InterPro-Version', b'100.0'), (b'Access-Control-Expose-Headers', b'Content-Length, InterPro-Version, Cached'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:16 GMT'), (b'Access-Control-Max-Age', b'3600'), (b'Server-Timing', b''), (b'InterPro-Version-Minor', b'1'), (b'Access-Control-Allow-Origin', b'*'), (b'X-Content-Type-Options', b'nosniff'), (b'Connection', b'Keep-Alive'), (b'Allow', b'GET, HEAD'), (b'X-Frame-Options', b'DENY'), (b'Access-Control-Allow-Methods', b'GET, HEAD, OPTIONS, POST, PUT'), (b'Access-Control-Allow-Headers', b'x-requested-with, Content-Type, origin, authorization, accept, client-security-token'), (b'Referrer-Policy', b'same-origin'), (b'Cached', b'true'), (b'Content-Length', b'2249')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/O59488 "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/O59488. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/proteins/api/proteins?format=json&accession=Q3IQF5
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/interpro/api/entry/interpro/protein/uniprot/Q18H49
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# ...
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2806419. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/156457
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2934938 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2934938. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2202151
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/156457 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/156457. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2569760
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2202151 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2202151. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/311400
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2569760 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2569760. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2250277
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/311400 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/311400. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2811097
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2250277 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2250277. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2081358
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2811097 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2811097. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/90426
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2081358 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2081358. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/1980981
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/90426 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/90426. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/313370
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/1980981 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/1980981. Code: 200
# DEBUG:pyeed.fetch.requester:Sending request to https://www.ebi.ac.uk/ena/browser/api/xml/2026739
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/313370 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/313370. Code: 200
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'', [(b'Vary', b'Origin'), (b'Vary', b'Access-Control-Request-Method'), (b'Vary', b'Access-Control-Request-Headers'), (b'Content-Type', b'application/xml'), (b'Strict-Transport-Security', b'max-age=0'), (b'Date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive')])
# INFO:httpx:HTTP Request: GET https://www.ebi.ac.uk/ena/browser/api/xml/2026739 "HTTP/1.1 200 "
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'GET']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:pyeed.fetch.requester:Received response from https://www.ebi.ac.uk/ena/browser/api/xml/2026739. Code: 200
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# ## Multi Sequence Alignment
#
# A multi sequence alignment can be calculated by creating a `MSA` object and passing a list of `ProteinRecord`. The alignment can be executed by calling the `clustalo` method. In order for the `clustalo` method to work, the PyEED Docker Service must be running. The `clustalo` method will return an `AlignmentResult` containing all input `sequences` and `aligned_sequences`.

# %%
from pyeed.align import MSA

alignment = MSA(sequences=sequences).clustalo()
alignment.visualize()
# Out:
# DEBUG:pyeed.tools.clustalo:Connecting to ClustalOmega service at http://clustalo:5001/align.
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/max/miniconda3/envs/pyeed/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpcore.connection:connect_tcp.started host='clustalo' port=5001 local_address=None timeout=600 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.failed exception=ConnectError(gaierror(8, 'nodename nor servname provided, or not known'))
# DEBUG:pyeed.tools.clustalo:ClustalOmega service not reachable at http://clustalo:5001/align.
# DEBUG:pyeed.tools.clustalo:Trying to connect to http://localhost:5001/align.
# DEBUG:httpx:load_ssl_context verify=True cert=None trust_env=True http2=False
# DEBUG:httpx:load_verify_locations cafile='/Users/max/miniconda3/envs/pyeed/lib/python3.11/site-packages/certifi/cacert.pem'
# DEBUG:httpcore.connection:connect_tcp.started host='localhost' port=5001 local_address=None timeout=600 socket_options=None
# DEBUG:httpcore.connection:connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x166d7e5d0>
# DEBUG:httpcore.http11:send_request_headers.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_headers.complete
# DEBUG:httpcore.http11:send_request_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:send_request_body.complete
# DEBUG:httpcore.http11:receive_response_headers.started request=<Request [b'POST']>
# Output()
# DEBUG:httpcore.http11:receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'date', b'Sat, 22 Jun 2024 09:47:27 GMT'), (b'server', b'uvicorn'), (b'content-length', b'41338'), (b'content-type', b'application/json')])
# INFO:httpx:HTTP Request: POST http://localhost:5001/align "HTTP/1.1 200 OK"
# DEBUG:httpcore.http11:receive_response_body.started request=<Request [b'POST']>
# DEBUG:httpcore.http11:receive_response_body.complete
# DEBUG:httpcore.http11:response_closed.started
# DEBUG:httpcore.http11:response_closed.complete
# DEBUG:httpcore.connection:close.started
# DEBUG:httpcore.connection:close.complete
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ✅ Alignment completed
# DEBUG:matplotlib.axes._base:top of Axes not in the figure, so title not moved
# DEBUG:matplotlib.axes._base:top of Axes not in the figure, so title not moved
# DEBUG:matplotlib.axes._base:top of Axes not in the figure, so title not moved

# %% [markdown]
# ## Create a HMM profile
#
# To create a hidden markov model profile, you can use the `HMM` class. This method receives a `MSA` object to create the model. To check if a sequence belongs to the profile, you can use the `search` method. This method takes a `ProteinRecord` object and returns a `HMMResult` object containing the `sequence` and the `score` of the sequence in the profile.

# %%
from pyeed.align import HMM

model = HMM(name="random profile", alignment=alignment)
hits = model.search(sequence=sequences[0])
